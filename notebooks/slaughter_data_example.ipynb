# %% [markdown]
# # BloodSampling Example
#
# This is an example of how to use the `SlaughterData` class to parse and use the data form the slaughter house csv files.

# %% [markdown]
# - Import the data parsers

# %%
import src.data as d

# %% [markdown]
# - Load the data from the input files and parse it into a more convenient format. (using the BloodSamplingData class)

# %%
file_path = "sample_files/Slacht Bult 4 EKRO 06-03-2024 2e.xls"
slaughterData = d.SlaughterData(file_path)
slaughterData.df.sample(10)
# Out:
# 0  ear_tag_number work_number     #      weight       type     color  \
# 39  DE 0365314745       14745  1333      179.69          9         7
# 86            NaN         NaN    85  151.978118  11.223529  6.517647
# 67  DE 0364657070       57070  1361      158.52         11         6
# 14  DE 1306702735       02735  1308       144.5         12         7
# 32  DE 1307009143       09143  1326      166.46         11         6
# 4   DE 0542723957       23957  1298      162.05         10         6
# 55  DE 1306952355       52355  1349      151.46         12         5
# 54  DE 1406973122       73122  1348      180.86         12         6
# 44  DE 0958957450       57450  1338      159.99         11         6
# 49  DE 1505453364       53364  1343      157.34         11         5
#
# 0        fat birth_date age_code   Sekse  ... calf overseer antibiotics  \
# 39         2 2023-07-20        V  STIER   ...  NaN      NaN         NaN
# ...

# %%
file_path = "sample_files/bult 1 slacht pali wk 41 156.5 kg,   .csv"
slaughterData = d.SlaughterData(file_path)
slaughterData.df.sample(10)
# Out:
#        #  sequence_number  couple ear_tag_number_full Type  fat_cover  color  \
# 75    76             7203       3     IE 214064222182   O+         30      5
# 220  221             8248       3     IE 216294331812   O-         20      5
# 50    51             7178       3     IE 222937487620   O+         30      6
# 176  177             7560       8     IE 223303492023   P+         20      5
# 321  322             8349       4     IE 219132993156   O-         20      8
# 326  327             8354       4     IE 224324442658   O0         20      9
# 186  187             8214       3     IE 216945983913   O0         20      6
# 22    23             7150       3     IE 222372132917   O0         20      5
# 152  153             7536       8     IE 216499252404   O+         20      5
# 127  128             7511       8     IE 222937467560   O-         20      5
#
#     sex weight correction      UBN birth_date slaughter_date housing category  \
# ...
